# %%
import scipy.io
anno_box = scipy.io.loadmat('/home/yuxuan/gpnn/tmp/hico/hico_20160224_det/anno_bbox.mat')

# %%
import numpy as np
from tqdm import tqdm
import scipy.io as scio

def create_hoi_list(anno):
    num_hoi = anno['list_action'].shape[0]
    hoi_list = [None]*num_hoi
    for i in range(num_hoi):
        hoi_list[i] = {
            'id': str(i+1).zfill(3),
            'object': anno['list_action'][i,0][0][0],
            'verb': anno['list_action'][i,0][1][0],
        }

    return hoi_list


def get_image_size(anno,i,subset):
    W = anno_bbox[f'bbox_{subset}'][0,i][1][0,0][0][0,0]
    H = anno_bbox[f'bbox_{subset}'][0,i][1][0,0][1][0,0]
    C = anno_bbox[f'bbox_{subset}'][0,i][1][0,0][2][0,0]
    image_size = [int(v) for v in [H,W,C]]
    return image_size


def get_hoi_bboxes(anno_bbox,i,subset):
    num_hois = anno_bbox[f'bbox_{subset}'][0,i][2].shape[1]
    hois = [None]*num_hois
    for j in range(num_hois):
        hoi_data = anno_bbox[f'bbox_{subset}'][0,i][2][0,j]

        hoi_id = str(hoi_data[0][0,0]).zfill(3)    

        num_boxes = hoi_data[1].shape[1]
        human_bboxes = [None]*num_boxes
        for b in range(num_boxes):
            human_bboxes[b] = \
                [int(hoi_data[1][0,b][k][0,0]-1) for k in [0,2,1,3]]

        num_boxes = hoi_data[2].shape[1]
        object_bboxes = [None]*num_boxes
        for b in range(num_boxes):
            object_bboxes[b] = \
                [int(hoi_data[2][0,b][k][0,0]-1) for k in [0,2,1,3]]

        connections = (hoi_data[3]-1).tolist()

        invis = int(hoi_data[4][0,0])

        hois[j] = {
            'id': hoi_id,
            'human_bboxes': human_bboxes,
            'object_bboxes': object_bboxes,
            'connections': connections,
            'invis': invis,
        }

    return hois

def create_anno_list(anno):
    anno_list = []
    for subset in ['train','test']:
        print(f'Adding {subset} data to anno list ...')
        num_samples = anno[f'anno_{subset}'].shape[1]
        for i in tqdm(range(num_samples)):
            image_jpg = anno[f'list_{subset}'][i][0][0]

            if image_jpg.endswith('.jpg'):
                global_id = image_jpg[:-4]
            else:
                assert(False), 'Image extension is not .jpg'

            anno = {
                'global_id': global_id,
                'image_path_postfix': f'{subset}2015/{image_jpg}',
                'image_size': self.get_image_size(i,subset),
                'hois': self.get_hoi_bboxes(i,subset)
            }

            anno['pos_hoi_ids'] = [str(k[0]+1).zfill(3) for k in \
                np.argwhere(self.anno[f'anno_{subset}'][:,i]==1).tolist()]
            anno['neg_hoi_ids'] = [str(k[0]+1).zfill(3) for k in \
                np.argwhere(self.anno[f'anno_{subset}'][:,i]==-1).tolist()]

            anno_list.append(anno)

    return anno_list

# %%
create_hoi_list(anno_box)
# Out:
# [{'id': '001', 'object': 'airplane', 'verb': 'board'},
#  {'id': '002', 'object': 'airplane', 'verb': 'direct'},
#  {'id': '003', 'object': 'airplane', 'verb': 'exit'},
#  {'id': '004', 'object': 'airplane', 'verb': 'fly'},
#  {'id': '005', 'object': 'airplane', 'verb': 'inspect'},
#  {'id': '006', 'object': 'airplane', 'verb': 'load'},
#  {'id': '007', 'object': 'airplane', 'verb': 'ride'},
#  {'id': '008', 'object': 'airplane', 'verb': 'sit_on'},
#  {'id': '009', 'object': 'airplane', 'verb': 'wash'},
#  {'id': '010', 'object': 'airplane', 'verb': 'no_interaction'},
#  {'id': '011', 'object': 'bicycle', 'verb': 'carry'},
#  {'id': '012', 'object': 'bicycle', 'verb': 'hold'},
#  {'id': '013', 'object': 'bicycle', 'verb': 'inspect'},
#  {'id': '014', 'object': 'bicycle', 'verb': 'jump'},
#  {'id': '015', 'object': 'bicycle', 'verb': 'hop_on'},
#  {'id': '016', 'object': 'bicycle', 'verb': 'park'},
#  {'id': '017', 'object': 'bicycle', 'verb': 'push'},
#  {'id': '018', 'object': 'bicycle', 'verb': 'repair'},
#  {'id': '019', 'object': 'bicycle', 'verb': 'ride'},
#  {'id': '020', 'object': 'bicycle', 'verb': 'sit_on'},
#  {'id': '021', 'object': 'bicycle', 'verb': 'straddle'},
#  {'id': '022', 'object': 'bicycle', 'verb': 'walk'},
#  {'id': '023', 'object': 'bicycle', 'verb': 'wash'},
#  {'id': '024', 'object': 'bicycle', 'verb': 'no_interaction'},
#  {'id': '025', 'object': 'bird', 'verb': 'chase'},
#  {'id': '026', 'object': 'bird', 'verb': 'feed'},
#  {'id': '027', 'object': 'bird', 'verb': 'hold'},
#  {'id': '028', 'object': 'bird', 'verb': 'pet'},
#  {'id': '029', 'object': 'bird', 'verb': 'release'},
#  {'id': '030', 'object': 'bird', 'verb': 'watch'},
#  {'id': '031', 'object': 'bird', 'verb': 'no_interaction'},
#  {'id': '032', 'object': 'boat', 'verb': 'board'},
#  {'id': '033', 'object': 'boat', 'verb': 'drive'},
#  {'id': '034', 'object': 'boat', 'verb': 'exit'},
#  {'id': '035', 'object': 'boat', 'verb': 'inspect'},
#  {'id': '036', 'object': 'boat', 'verb': 'jump'},
#  {'id': '037', 'object': 'boat', 'verb': 'launch'},
#  {'id': '038', 'object': 'boat', 'verb': 'repair'},
#  {'id': '039', 'object': 'boat', 'verb': 'ride'},
#  {'id': '040', 'object': 'boat', 'verb': 'row'},
#  {'id': '041', 'object': 'boat', 'verb': 'sail'},
#  {'id': '042', 'object': 'boat', 'verb': 'sit_on'},
#  {'id': '043', 'object': 'boat', 'verb': 'stand_on'},
#  {'id': '044', 'object': 'boat', 'verb': 'tie'},
#  {'id': '045', 'object': 'boat', 'verb': 'wash'},
#  {'id': '046', 'object': 'boat', 'verb': 'no_interaction'},
#  {'id': '047', 'object': 'bottle', 'verb': 'carry'},
#  {'id': '048', 'object': 'bottle', 'verb': 'drink_with'},
#  {'id': '049', 'object': 'bottle', 'verb': 'hold'},
#  {'id': '050', 'object': 'bottle', 'verb': 'inspect'},
#  {'id': '051', 'object': 'bottle', 'verb': 'lick'},
#  {'id': '052', 'object': 'bottle', 'verb': 'open'},
#  {'id': '053', 'object': 'bottle', 'verb': 'pour'},
#  {'id': '054', 'object': 'bottle', 'verb': 'no_interaction'},
#  {'id': '055', 'object': 'bus', 'verb': 'board'},
#  {'id': '056', 'object': 'bus', 'verb': 'direct'},
#  {'id': '057', 'object': 'bus', 'verb': 'drive'},
#  {'id': '058', 'object': 'bus', 'verb': 'exit'},
#  {'id': '059', 'object': 'bus', 'verb': 'inspect'},
#  {'id': '060', 'object': 'bus', 'verb': 'load'},
#  {'id': '061', 'object': 'bus', 'verb': 'ride'},
#  {'id': '062', 'object': 'bus', 'verb': 'sit_on'},
#  {'id': '063', 'object': 'bus', 'verb': 'wash'},
#  {'id': '064', 'object': 'bus', 'verb': 'wave'},
#  {'id': '065', 'object': 'bus', 'verb': 'no_interaction'},
#  {'id': '066', 'object': 'car', 'verb': 'board'},
#  {'id': '067', 'object': 'car', 'verb': 'direct'},
#  {'id': '068', 'object': 'car', 'verb': 'drive'},
#  {'id': '069', 'object': 'car', 'verb': 'hose'},
#  {'id': '070', 'object': 'car', 'verb': 'inspect'},
#  {'id': '071', 'object': 'car', 'verb': 'jump'},
#  {'id': '072', 'object': 'car', 'verb': 'load'},
#  {'id': '073', 'object': 'car', 'verb': 'park'},
#  {'id': '074', 'object': 'car', 'verb': 'ride'},
#  {'id': '075', 'object': 'car', 'verb': 'wash'},
#  {'id': '076', 'object': 'car', 'verb': 'no_interaction'},
#  {'id': '077', 'object': 'cat', 'verb': 'dry'},
#  {'id': '078', 'object': 'cat', 'verb': 'feed'},
#  {'id': '079', 'object': 'cat', 'verb': 'hold'},
#  {'id': '080', 'object': 'cat', 'verb': 'hug'},
#  {'id': '081', 'object': 'cat', 'verb': 'kiss'},
#  {'id': '082', 'object': 'cat', 'verb': 'pet'},
#  {'id': '083', 'object': 'cat', 'verb': 'scratch'},
#  {'id': '084', 'object': 'cat', 'verb': 'wash'},
#  {'id': '085', 'object': 'cat', 'verb': 'chase'},
#  {'id': '086', 'object': 'cat', 'verb': 'no_interaction'},
#  {'id': '087', 'object': 'chair', 'verb': 'carry'},
#  {'id': '088', 'object': 'chair', 'verb': 'hold'},
#  {'id': '089', 'object': 'chair', 'verb': 'lie_on'},
#  {'id': '090', 'object': 'chair', 'verb': 'sit_on'},
#  {'id': '091', 'object': 'chair', 'verb': 'stand_on'},
#  {'id': '092', 'object': 'chair', 'verb': 'no_interaction'},
#  {'id': '093', 'object': 'couch', 'verb': 'carry'},
#  {'id': '094', 'object': 'couch', 'verb': 'lie_on'},
#  {'id': '095', 'object': 'couch', 'verb': 'sit_on'},
#  {'id': '096', 'object': 'couch', 'verb': 'no_interaction'},
#  {'id': '097', 'object': 'cow', 'verb': 'feed'},
#  {'id': '098', 'object': 'cow', 'verb': 'herd'},
#  {'id': '099', 'object': 'cow', 'verb': 'hold'},
#  {'id': '100', 'object': 'cow', 'verb': 'hug'},
#  {'id': '101', 'object': 'cow', 'verb': 'kiss'},
#  {'id': '102', 'object': 'cow', 'verb': 'lasso'},
#  {'id': '103', 'object': 'cow', 'verb': 'milk'},
#  {'id': '104', 'object': 'cow', 'verb': 'pet'},
#  {'id': '105', 'object': 'cow', 'verb': 'ride'},
#  {'id': '106', 'object': 'cow', 'verb': 'walk'},
#  {'id': '107', 'object': 'cow', 'verb': 'no_interaction'},
#  {'id': '108', 'object': 'dining_table', 'verb': 'clean'},
#  {'id': '109', 'object': 'dining_table', 'verb': 'eat_at'},
#  {'id': '110', 'object': 'dining_table', 'verb': 'sit_at'},
#  {'id': '111', 'object': 'dining_table', 'verb': 'no_interaction'},
#  {'id': '112', 'object': 'dog', 'verb': 'carry'},
#  {'id': '113', 'object': 'dog', 'verb': 'dry'},
#  {'id': '114', 'object': 'dog', 'verb': 'feed'},
#  {'id': '115', 'object': 'dog', 'verb': 'groom'},
#  {'id': '116', 'object': 'dog', 'verb': 'hold'},
#  {'id': '117', 'object': 'dog', 'verb': 'hose'},
#  {'id': '118', 'object': 'dog', 'verb': 'hug'},
#  {'id': '119', 'object': 'dog', 'verb': 'inspect'},
#  {'id': '120', 'object': 'dog', 'verb': 'kiss'},
#  {'id': '121', 'object': 'dog', 'verb': 'pet'},
#  {'id': '122', 'object': 'dog', 'verb': 'run'},
#  {'id': '123', 'object': 'dog', 'verb': 'scratch'},
#  {'id': '124', 'object': 'dog', 'verb': 'straddle'},
#  {'id': '125', 'object': 'dog', 'verb': 'train'},
#  {'id': '126', 'object': 'dog', 'verb': 'walk'},
#  {'id': '127', 'object': 'dog', 'verb': 'wash'},
#  {'id': '128', 'object': 'dog', 'verb': 'chase'},
#  {'id': '129', 'object': 'dog', 'verb': 'no_interaction'},
#  {'id': '130', 'object': 'horse', 'verb': 'feed'},
#  {'id': '131', 'object': 'horse', 'verb': 'groom'},
#  {'id': '132', 'object': 'horse', 'verb': 'hold'},
#  {'id': '133', 'object': 'horse', 'verb': 'hug'},
#  {'id': '134', 'object': 'horse', 'verb': 'jump'},
#  {'id': '135', 'object': 'horse', 'verb': 'kiss'},
#  {'id': '136', 'object': 'horse', 'verb': 'load'},
#  {'id': '137', 'object': 'horse', 'verb': 'hop_on'},
#  {'id': '138', 'object': 'horse', 'verb': 'pet'},
#  {'id': '139', 'object': 'horse', 'verb': 'race'},
#  {'id': '140', 'object': 'horse', 'verb': 'ride'},
#  {'id': '141', 'object': 'horse', 'verb': 'run'},
#  {'id': '142', 'object': 'horse', 'verb': 'straddle'},
#  {'id': '143', 'object': 'horse', 'verb': 'train'},
#  {'id': '144', 'object': 'horse', 'verb': 'walk'},
#  {'id': '145', 'object': 'horse', 'verb': 'wash'},
#  {'id': '146', 'object': 'horse', 'verb': 'no_interaction'},
#  {'id': '147', 'object': 'motorcycle', 'verb': 'hold'},
#  {'id': '148', 'object': 'motorcycle', 'verb': 'inspect'},
#  {'id': '149', 'object': 'motorcycle', 'verb': 'jump'},
#  {'id': '150', 'object': 'motorcycle', 'verb': 'hop_on'},
#  {'id': '151', 'object': 'motorcycle', 'verb': 'park'},
#  {'id': '152', 'object': 'motorcycle', 'verb': 'push'},
#  {'id': '153', 'object': 'motorcycle', 'verb': 'race'},
#  {'id': '154', 'object': 'motorcycle', 'verb': 'ride'},
#  {'id': '155', 'object': 'motorcycle', 'verb': 'sit_on'},
#  {'id': '156', 'object': 'motorcycle', 'verb': 'straddle'},
#  {'id': '157', 'object': 'motorcycle', 'verb': 'turn'},
#  {'id': '158', 'object': 'motorcycle', 'verb': 'walk'},
#  {'id': '159', 'object': 'motorcycle', 'verb': 'wash'},
#  {'id': '160', 'object': 'motorcycle', 'verb': 'no_interaction'},
#  {'id': '161', 'object': 'person', 'verb': 'carry'},
#  {'id': '162', 'object': 'person', 'verb': 'greet'},
#  {'id': '163', 'object': 'person', 'verb': 'hold'},
#  {'id': '164', 'object': 'person', 'verb': 'hug'},
#  {'id': '165', 'object': 'person', 'verb': 'kiss'},
#  {'id': '166', 'object': 'person', 'verb': 'stab'},
#  {'id': '167', 'object': 'person', 'verb': 'tag'},
#  {'id': '168', 'object': 'person', 'verb': 'teach'},
#  {'id': '169', 'object': 'person', 'verb': 'lick'},
#  {'id': '170', 'object': 'person', 'verb': 'no_interaction'},
#  {'id': '171', 'object': 'potted_plant', 'verb': 'carry'},
#  {'id': '172', 'object': 'potted_plant', 'verb': 'hold'},
#  {'id': '173', 'object': 'potted_plant', 'verb': 'hose'},
#  {'id': '174', 'object': 'potted_plant', 'verb': 'no_interaction'},
#  {'id': '175', 'object': 'sheep', 'verb': 'carry'},
#  {'id': '176', 'object': 'sheep', 'verb': 'feed'},
#  {'id': '177', 'object': 'sheep', 'verb': 'herd'},
#  {'id': '178', 'object': 'sheep', 'verb': 'hold'},
#  {'id': '179', 'object': 'sheep', 'verb': 'hug'},
#  {'id': '180', 'object': 'sheep', 'verb': 'kiss'},
#  {'id': '181', 'object': 'sheep', 'verb': 'pet'},
#  {'id': '182', 'object': 'sheep', 'verb': 'ride'},
#  {'id': '183', 'object': 'sheep', 'verb': 'shear'},
#  {'id': '184', 'object': 'sheep', 'verb': 'walk'},
#  {'id': '185', 'object': 'sheep', 'verb': 'wash'},
#  {'id': '186', 'object': 'sheep', 'verb': 'no_interaction'},
#  {'id': '187', 'object': 'train', 'verb': 'board'},
#  {'id': '188', 'object': 'train', 'verb': 'drive'},
#  {'id': '189', 'object': 'train', 'verb': 'exit'},
#  {'id': '190', 'object': 'train', 'verb': 'load'},
#  {'id': '191', 'object': 'train', 'verb': 'ride'},
#  {'id': '192', 'object': 'train', 'verb': 'sit_on'},
#  {'id': '193', 'object': 'train', 'verb': 'wash'},
#  {'id': '194', 'object': 'train', 'verb': 'no_interaction'},
#  {'id': '195', 'object': 'tv', 'verb': 'control'},
#  {'id': '196', 'object': 'tv', 'verb': 'repair'},
#  {'id': '197', 'object': 'tv', 'verb': 'watch'},
#  {'id': '198', 'object': 'tv', 'verb': 'no_interaction'},
#  {'id': '199', 'object': 'apple', 'verb': 'buy'},
#  {'id': '200', 'object': 'apple', 'verb': 'cut'},
#  {'id': '201', 'object': 'apple', 'verb': 'eat'},
#  {'id': '202', 'object': 'apple', 'verb': 'hold'},
#  {'id': '203', 'object': 'apple', 'verb': 'inspect'},
#  {'id': '204', 'object': 'apple', 'verb': 'peel'},
#  {'id': '205', 'object': 'apple', 'verb': 'pick'},
#  {'id': '206', 'object': 'apple', 'verb': 'smell'},
#  {'id': '207', 'object': 'apple', 'verb': 'wash'},
#  {'id': '208', 'object': 'apple', 'verb': 'no_interaction'},
#  {'id': '209', 'object': 'backpack', 'verb': 'carry'},
#  {'id': '210', 'object': 'backpack', 'verb': 'hold'},
#  {'id': '211', 'object': 'backpack', 'verb': 'inspect'},
#  {'id': '212', 'object': 'backpack', 'verb': 'open'},
#  {'id': '213', 'object': 'backpack', 'verb': 'wear'},
#  {'id': '214', 'object': 'backpack', 'verb': 'no_interaction'},
#  {'id': '215', 'object': 'banana', 'verb': 'buy'},
#  {'id': '216', 'object': 'banana', 'verb': 'carry'},
#  {'id': '217', 'object': 'banana', 'verb': 'cut'},
#  {'id': '218', 'object': 'banana', 'verb': 'eat'},
#  {'id': '219', 'object': 'banana', 'verb': 'hold'},
#  {'id': '220', 'object': 'banana', 'verb': 'inspect'},
#  {'id': '221', 'object': 'banana', 'verb': 'peel'},
#  {'id': '222', 'object': 'banana', 'verb': 'pick'},
#  {'id': '223', 'object': 'banana', 'verb': 'smell'},
#  {'id': '224', 'object': 'banana', 'verb': 'no_interaction'},
#  {'id': '225', 'object': 'baseball_bat', 'verb': 'break'},
#  {'id': '226', 'object': 'baseball_bat', 'verb': 'carry'},
#  {'id': '227', 'object': 'baseball_bat', 'verb': 'hold'},
#  {'id': '228', 'object': 'baseball_bat', 'verb': 'sign'},
#  {'id': '229', 'object': 'baseball_bat', 'verb': 'swing'},
#  {'id': '230', 'object': 'baseball_bat', 'verb': 'throw'},
#  {'id': '231', 'object': 'baseball_bat', 'verb': 'wield'},
#  {'id': '232', 'object': 'baseball_bat', 'verb': 'no_interaction'},
#  {'id': '233', 'object': 'baseball_glove', 'verb': 'hold'},
#  {'id': '234', 'object': 'baseball_glove', 'verb': 'wear'},
#  {'id': '235', 'object': 'baseball_glove', 'verb': 'no_interaction'},
#  {'id': '236', 'object': 'bear', 'verb': 'feed'},
#  {'id': '237', 'object': 'bear', 'verb': 'hunt'},
#  {'id': '238', 'object': 'bear', 'verb': 'watch'},
#  {'id': '239', 'object': 'bear', 'verb': 'no_interaction'},
#  {'id': '240', 'object': 'bed', 'verb': 'clean'},
#  {'id': '241', 'object': 'bed', 'verb': 'lie_on'},
#  {'id': '242', 'object': 'bed', 'verb': 'sit_on'},
#  {'id': '243', 'object': 'bed', 'verb': 'no_interaction'},
#  {'id': '244', 'object': 'bench', 'verb': 'inspect'},
#  {'id': '245', 'object': 'bench', 'verb': 'lie_on'},
#  {'id': '246', 'object': 'bench', 'verb': 'sit_on'},
#  {'id': '247', 'object': 'bench', 'verb': 'no_interaction'},
#  {'id': '248', 'object': 'book', 'verb': 'carry'},
#  {'id': '249', 'object': 'book', 'verb': 'hold'},
#  {'id': '250', 'object': 'book', 'verb': 'open'},
#  {'id': '251', 'object': 'book', 'verb': 'read'},
#  {'id': '252', 'object': 'book', 'verb': 'no_interaction'},
#  {'id': '253', 'object': 'bowl', 'verb': 'hold'},
#  {'id': '254', 'object': 'bowl', 'verb': 'stir'},
#  {'id': '255', 'object': 'bowl', 'verb': 'wash'},
#  {'id': '256', 'object': 'bowl', 'verb': 'lick'},
#  {'id': '257', 'object': 'bowl', 'verb': 'no_interaction'},
#  {'id': '258', 'object': 'broccoli', 'verb': 'cut'},
#  {'id': '259', 'object': 'broccoli', 'verb': 'eat'},
#  {'id': '260', 'object': 'broccoli', 'verb': 'hold'},
#  {'id': '261', 'object': 'broccoli', 'verb': 'smell'},
#  {'id': '262', 'object': 'broccoli', 'verb': 'stir'},
#  {'id': '263', 'object': 'broccoli', 'verb': 'wash'},
#  {'id': '264', 'object': 'broccoli', 'verb': 'no_interaction'},
#  {'id': '265', 'object': 'cake', 'verb': 'blow'},
#  {'id': '266', 'object': 'cake', 'verb': 'carry'},
#  {'id': '267', 'object': 'cake', 'verb': 'cut'},
#  {'id': '268', 'object': 'cake', 'verb': 'eat'},
#  {'id': '269', 'object': 'cake', 'verb': 'hold'},
#  {'id': '270', 'object': 'cake', 'verb': 'light'},
#  {'id': '271', 'object': 'cake', 'verb': 'make'},
#  {'id': '272', 'object': 'cake', 'verb': 'pick_up'},
#  {'id': '273', 'object': 'cake', 'verb': 'no_interaction'},
#  {'id': '274', 'object': 'carrot', 'verb': 'carry'},
#  {'id': '275', 'object': 'carrot', 'verb': 'cook'},
#  {'id': '276', 'object': 'carrot', 'verb': 'cut'},
#  {'id': '277', 'object': 'carrot', 'verb': 'eat'},
#  {'id': '278', 'object': 'carrot', 'verb': 'hold'},
#  {'id': '279', 'object': 'carrot', 'verb': 'peel'},
#  {'id': '280', 'object': 'carrot', 'verb': 'smell'},
#  {'id': '281', 'object': 'carrot', 'verb': 'stir'},
#  {'id': '282', 'object': 'carrot', 'verb': 'wash'},
#  {'id': '283', 'object': 'carrot', 'verb': 'no_interaction'},
#  {'id': '284', 'object': 'cell_phone', 'verb': 'carry'},
#  {'id': '285', 'object': 'cell_phone', 'verb': 'hold'},
#  {'id': '286', 'object': 'cell_phone', 'verb': 'read'},
#  {'id': '287', 'object': 'cell_phone', 'verb': 'repair'},
#  {'id': '288', 'object': 'cell_phone', 'verb': 'talk_on'},
#  {'id': '289', 'object': 'cell_phone', 'verb': 'text_on'},
#  {'id': '290', 'object': 'cell_phone', 'verb': 'no_interaction'},
#  {'id': '291', 'object': 'clock', 'verb': 'check'},
#  {'id': '292', 'object': 'clock', 'verb': 'hold'},
#  {'id': '293', 'object': 'clock', 'verb': 'repair'},
#  {'id': '294', 'object': 'clock', 'verb': 'set'},
#  {'id': '295', 'object': 'clock', 'verb': 'no_interaction'},
#  {'id': '296', 'object': 'cup', 'verb': 'carry'},
#  {'id': '297', 'object': 'cup', 'verb': 'drink_with'},
#  {'id': '298', 'object': 'cup', 'verb': 'hold'},
#  {'id': '299', 'object': 'cup', 'verb': 'inspect'},
#  {'id': '300', 'object': 'cup', 'verb': 'pour'},
#  {'id': '301', 'object': 'cup', 'verb': 'sip'},
#  {'id': '302', 'object': 'cup', 'verb': 'smell'},
#  {'id': '303', 'object': 'cup', 'verb': 'fill'},
#  {'id': '304', 'object': 'cup', 'verb': 'wash'},
#  {'id': '305', 'object': 'cup', 'verb': 'no_interaction'},
#  {'id': '306', 'object': 'donut', 'verb': 'buy'},
#  {'id': '307', 'object': 'donut', 'verb': 'carry'},
#  {'id': '308', 'object': 'donut', 'verb': 'eat'},
#  {'id': '309', 'object': 'donut', 'verb': 'hold'},
#  {'id': '310', 'object': 'donut', 'verb': 'make'},
#  {'id': '311', 'object': 'donut', 'verb': 'pick_up'},
#  {'id': '312', 'object': 'donut', 'verb': 'smell'},
#  {'id': '313', 'object': 'donut', 'verb': 'no_interaction'},
#  {'id': '314', 'object': 'elephant', 'verb': 'feed'},
#  {'id': '315', 'object': 'elephant', 'verb': 'hold'},
#  {'id': '316', 'object': 'elephant', 'verb': 'hose'},
#  {'id': '317', 'object': 'elephant', 'verb': 'hug'},
#  {'id': '318', 'object': 'elephant', 'verb': 'kiss'},
#  {'id': '319', 'object': 'elephant', 'verb': 'hop_on'},
#  {'id': '320', 'object': 'elephant', 'verb': 'pet'},
#  {'id': '321', 'object': 'elephant', 'verb': 'ride'},
#  {'id': '322', 'object': 'elephant', 'verb': 'walk'},
#  {'id': '323', 'object': 'elephant', 'verb': 'wash'},
#  {'id': '324', 'object': 'elephant', 'verb': 'watch'},
#  {'id': '325', 'object': 'elephant', 'verb': 'no_interaction'},
#  {'id': '326', 'object': 'fire_hydrant', 'verb': 'hug'},
#  {'id': '327', 'object': 'fire_hydrant', 'verb': 'inspect'},
#  {'id': '328', 'object': 'fire_hydrant', 'verb': 'open'},
#  {'id': '329', 'object': 'fire_hydrant', 'verb': 'paint'},
#  {'id': '330', 'object': 'fire_hydrant', 'verb': 'no_interaction'},
#  {'id': '331', 'object': 'fork', 'verb': 'hold'},
#  {'id': '332', 'object': 'fork', 'verb': 'lift'},
#  {'id': '333', 'object': 'fork', 'verb': 'stick'},
#  {'id': '334', 'object': 'fork', 'verb': 'lick'},
#  {'id': '335', 'object': 'fork', 'verb': 'wash'},
#  {'id': '336', 'object': 'fork', 'verb': 'no_interaction'},
#  {'id': '337', 'object': 'frisbee', 'verb': 'block'},
#  {'id': '338', 'object': 'frisbee', 'verb': 'catch'},
#  {'id': '339', 'object': 'frisbee', 'verb': 'hold'},
#  {'id': '340', 'object': 'frisbee', 'verb': 'spin'},
#  {'id': '341', 'object': 'frisbee', 'verb': 'throw'},
#  {'id': '342', 'object': 'frisbee', 'verb': 'no_interaction'},
#  {'id': '343', 'object': 'giraffe', 'verb': 'feed'},
#  {'id': '344', 'object': 'giraffe', 'verb': 'kiss'},
#  {'id': '345', 'object': 'giraffe', 'verb': 'pet'},
#  {'id': '346', 'object': 'giraffe', 'verb': 'ride'},
#  {'id': '347', 'object': 'giraffe', 'verb': 'watch'},
#  {'id': '348', 'object': 'giraffe', 'verb': 'no_interaction'},
#  {'id': '349', 'object': 'hair_drier', 'verb': 'hold'},
#  {'id': '350', 'object': 'hair_drier', 'verb': 'operate'},
#  {'id': '351', 'object': 'hair_drier', 'verb': 'repair'},
#  {'id': '352', 'object': 'hair_drier', 'verb': 'no_interaction'},
#  {'id': '353', 'object': 'handbag', 'verb': 'carry'},
#  {'id': '354', 'object': 'handbag', 'verb': 'hold'},
#  {'id': '355', 'object': 'handbag', 'verb': 'inspect'},
#  {'id': '356', 'object': 'handbag', 'verb': 'no_interaction'},
#  {'id': '357', 'object': 'hot_dog', 'verb': 'carry'},
#  {'id': '358', 'object': 'hot_dog', 'verb': 'cook'},
#  {'id': '359', 'object': 'hot_dog', 'verb': 'cut'},
#  {'id': '360', 'object': 'hot_dog', 'verb': 'eat'},
#  {'id': '361', 'object': 'hot_dog', 'verb': 'hold'},
#  {'id': '362', 'object': 'hot_dog', 'verb': 'make'},
#  {'id': '363', 'object': 'hot_dog', 'verb': 'no_interaction'},
#  {'id': '364', 'object': 'keyboard', 'verb': 'carry'},
#  {'id': '365', 'object': 'keyboard', 'verb': 'clean'},
#  {'id': '366', 'object': 'keyboard', 'verb': 'hold'},
#  {'id': '367', 'object': 'keyboard', 'verb': 'type_on'},
#  {'id': '368', 'object': 'keyboard', 'verb': 'no_interaction'},
#  {'id': '369', 'object': 'kite', 'verb': 'assemble'},
#  {'id': '370', 'object': 'kite', 'verb': 'carry'},
#  {'id': '371', 'object': 'kite', 'verb': 'fly'},
#  {'id': '372', 'object': 'kite', 'verb': 'hold'},
#  {'id': '373', 'object': 'kite', 'verb': 'inspect'},
#  {'id': '374', 'object': 'kite', 'verb': 'launch'},
#  {'id': '375', 'object': 'kite', 'verb': 'pull'},
#  {'id': '376', 'object': 'kite', 'verb': 'no_interaction'},
#  {'id': '377', 'object': 'knife', 'verb': 'cut_with'},
#  {'id': '378', 'object': 'knife', 'verb': 'hold'},
#  {'id': '379', 'object': 'knife', 'verb': 'stick'},
#  {'id': '380', 'object': 'knife', 'verb': 'wash'},
#  {'id': '381', 'object': 'knife', 'verb': 'wield'},
#  {'id': '382', 'object': 'knife', 'verb': 'lick'},
#  {'id': '383', 'object': 'knife', 'verb': 'no_interaction'},
#  {'id': '384', 'object': 'laptop', 'verb': 'hold'},
#  {'id': '385', 'object': 'laptop', 'verb': 'open'},
#  {'id': '386', 'object': 'laptop', 'verb': 'read'},
#  {'id': '387', 'object': 'laptop', 'verb': 'repair'},
#  {'id': '388', 'object': 'laptop', 'verb': 'type_on'},
#  {'id': '389', 'object': 'laptop', 'verb': 'no_interaction'},
#  {'id': '390', 'object': 'microwave', 'verb': 'clean'},
#  {'id': '391', 'object': 'microwave', 'verb': 'open'},
#  {'id': '392', 'object': 'microwave', 'verb': 'operate'},
#  {'id': '393', 'object': 'microwave', 'verb': 'no_interaction'},
#  {'id': '394', 'object': 'mouse', 'verb': 'control'},
#  {'id': '395', 'object': 'mouse', 'verb': 'hold'},
#  {'id': '396', 'object': 'mouse', 'verb': 'repair'},
#  {'id': '397', 'object': 'mouse', 'verb': 'no_interaction'},
#  {'id': '398', 'object': 'orange', 'verb': 'buy'},
#  {'id': '399', 'object': 'orange', 'verb': 'cut'},
#  {'id': '400', 'object': 'orange', 'verb': 'eat'},
#  {'id': '401', 'object': 'orange', 'verb': 'hold'},
#  {'id': '402', 'object': 'orange', 'verb': 'inspect'},
#  {'id': '403', 'object': 'orange', 'verb': 'peel'},
#  {'id': '404', 'object': 'orange', 'verb': 'pick'},
#  {'id': '405', 'object': 'orange', 'verb': 'squeeze'},
#  {'id': '406', 'object': 'orange', 'verb': 'wash'},
#  {'id': '407', 'object': 'orange', 'verb': 'no_interaction'},
#  {'id': '408', 'object': 'oven', 'verb': 'clean'},
#  {'id': '409', 'object': 'oven', 'verb': 'hold'},
#  {'id': '410', 'object': 'oven', 'verb': 'inspect'},
#  {'id': '411', 'object': 'oven', 'verb': 'open'},
#  {'id': '412', 'object': 'oven', 'verb': 'repair'},
#  {'id': '413', 'object': 'oven', 'verb': 'operate'},
#  {'id': '414', 'object': 'oven', 'verb': 'no_interaction'},
#  {'id': '415', 'object': 'parking_meter', 'verb': 'check'},
#  {'id': '416', 'object': 'parking_meter', 'verb': 'pay'},
#  {'id': '417', 'object': 'parking_meter', 'verb': 'repair'},
#  {'id': '418', 'object': 'parking_meter', 'verb': 'no_interaction'},
#  {'id': '419', 'object': 'pizza', 'verb': 'buy'},
#  {'id': '420', 'object': 'pizza', 'verb': 'carry'},
#  {'id': '421', 'object': 'pizza', 'verb': 'cook'},
#  {'id': '422', 'object': 'pizza', 'verb': 'cut'},
#  {'id': '423', 'object': 'pizza', 'verb': 'eat'},
#  {'id': '424', 'object': 'pizza', 'verb': 'hold'},
#  {'id': '425', 'object': 'pizza', 'verb': 'make'},
#  {'id': '426', 'object': 'pizza', 'verb': 'pick_up'},
#  {'id': '427', 'object': 'pizza', 'verb': 'slide'},
#  {'id': '428', 'object': 'pizza', 'verb': 'smell'},
#  {'id': '429', 'object': 'pizza', 'verb': 'no_interaction'},
#  {'id': '430', 'object': 'refrigerator', 'verb': 'clean'},
#  {'id': '431', 'object': 'refrigerator', 'verb': 'hold'},
#  {'id': '432', 'object': 'refrigerator', 'verb': 'move'},
#  {'id': '433', 'object': 'refrigerator', 'verb': 'open'},
#  {'id': '434', 'object': 'refrigerator', 'verb': 'no_interaction'},
#  {'id': '435', 'object': 'remote', 'verb': 'hold'},
#  {'id': '436', 'object': 'remote', 'verb': 'point'},
#  {'id': '437', 'object': 'remote', 'verb': 'swing'},
#  {'id': '438', 'object': 'remote', 'verb': 'no_interaction'},
#  {'id': '439', 'object': 'sandwich', 'verb': 'carry'},
#  {'id': '440', 'object': 'sandwich', 'verb': 'cook'},
#  {'id': '441', 'object': 'sandwich', 'verb': 'cut'},
#  {'id': '442', 'object': 'sandwich', 'verb': 'eat'},
#  {'id': '443', 'object': 'sandwich', 'verb': 'hold'},
#  {'id': '444', 'object': 'sandwich', 'verb': 'make'},
#  {'id': '445', 'object': 'sandwich', 'verb': 'no_interaction'},
#  {'id': '446', 'object': 'scissors', 'verb': 'cut_with'},
#  {'id': '447', 'object': 'scissors', 'verb': 'hold'},
#  {'id': '448', 'object': 'scissors', 'verb': 'open'},
#  {'id': '449', 'object': 'scissors', 'verb': 'no_interaction'},
#  {'id': '450', 'object': 'sink', 'verb': 'clean'},
#  {'id': '451', 'object': 'sink', 'verb': 'repair'},
#  {'id': '452', 'object': 'sink', 'verb': 'wash'},
#  {'id': '453', 'object': 'sink', 'verb': 'no_interaction'},
#  {'id': '454', 'object': 'skateboard', 'verb': 'carry'},
#  {'id': '455', 'object': 'skateboard', 'verb': 'flip'},
#  {'id': '456', 'object': 'skateboard', 'verb': 'grind'},
#  {'id': '457', 'object': 'skateboard', 'verb': 'hold'},
#  {'id': '458', 'object': 'skateboard', 'verb': 'jump'},
#  {'id': '459', 'object': 'skateboard', 'verb': 'pick_up'},
#  {'id': '460', 'object': 'skateboard', 'verb': 'ride'},
#  {'id': '461', 'object': 'skateboard', 'verb': 'sit_on'},
#  {'id': '462', 'object': 'skateboard', 'verb': 'stand_on'},
#  {'id': '463', 'object': 'skateboard', 'verb': 'no_interaction'},
#  {'id': '464', 'object': 'skis', 'verb': 'adjust'},
#  {'id': '465', 'object': 'skis', 'verb': 'carry'},
#  {'id': '466', 'object': 'skis', 'verb': 'hold'},
#  {'id': '467', 'object': 'skis', 'verb': 'inspect'},
#  {'id': '468', 'object': 'skis', 'verb': 'jump'},
#  {'id': '469', 'object': 'skis', 'verb': 'pick_up'},
#  {'id': '470', 'object': 'skis', 'verb': 'repair'},
#  {'id': '471', 'object': 'skis', 'verb': 'ride'},
#  {'id': '472', 'object': 'skis', 'verb': 'stand_on'},
#  {'id': '473', 'object': 'skis', 'verb': 'wear'},
#  {'id': '474', 'object': 'skis', 'verb': 'no_interaction'},
#  {'id': '475', 'object': 'snowboard', 'verb': 'adjust'},
#  {'id': '476', 'object': 'snowboard', 'verb': 'carry'},
#  {'id': '477', 'object': 'snowboard', 'verb': 'grind'},
#  {'id': '478', 'object': 'snowboard', 'verb': 'hold'},
#  {'id': '479', 'object': 'snowboard', 'verb': 'jump'},
#  {'id': '480', 'object': 'snowboard', 'verb': 'ride'},
#  {'id': '481', 'object': 'snowboard', 'verb': 'stand_on'},
#  {'id': '482', 'object': 'snowboard', 'verb': 'wear'},
#  {'id': '483', 'object': 'snowboard', 'verb': 'no_interaction'},
#  {'id': '484', 'object': 'spoon', 'verb': 'hold'},
#  {'id': '485', 'object': 'spoon', 'verb': 'lick'},
#  {'id': '486', 'object': 'spoon', 'verb': 'wash'},
#  {'id': '487', 'object': 'spoon', 'verb': 'sip'},
#  {'id': '488', 'object': 'spoon', 'verb': 'no_interaction'},
#  {'id': '489', 'object': 'sports_ball', 'verb': 'block'},
#  {'id': '490', 'object': 'sports_ball', 'verb': 'carry'},
#  {'id': '491', 'object': 'sports_ball', 'verb': 'catch'},
#  {'id': '492', 'object': 'sports_ball', 'verb': 'dribble'},
#  {'id': '493', 'object': 'sports_ball', 'verb': 'hit'},
#  {'id': '494', 'object': 'sports_ball', 'verb': 'hold'},
#  {'id': '495', 'object': 'sports_ball', 'verb': 'inspect'},
#  {'id': '496', 'object': 'sports_ball', 'verb': 'kick'},
#  {'id': '497', 'object': 'sports_ball', 'verb': 'pick_up'},
#  {'id': '498', 'object': 'sports_ball', 'verb': 'serve'},
#  {'id': '499', 'object': 'sports_ball', 'verb': 'sign'},
#  {'id': '500', 'object': 'sports_ball', 'verb': 'spin'},
#  {'id': '501', 'object': 'sports_ball', 'verb': 'throw'},
#  {'id': '502', 'object': 'sports_ball', 'verb': 'no_interaction'},
#  {'id': '503', 'object': 'stop_sign', 'verb': 'hold'},
#  {'id': '504', 'object': 'stop_sign', 'verb': 'stand_under'},
#  {'id': '505', 'object': 'stop_sign', 'verb': 'stop_at'},
#  {'id': '506', 'object': 'stop_sign', 'verb': 'no_interaction'},
#  {'id': '507', 'object': 'suitcase', 'verb': 'carry'},
#  {'id': '508', 'object': 'suitcase', 'verb': 'drag'},
#  {'id': '509', 'object': 'suitcase', 'verb': 'hold'},
#  {'id': '510', 'object': 'suitcase', 'verb': 'hug'},
#  {'id': '511', 'object': 'suitcase', 'verb': 'load'},
#  {'id': '512', 'object': 'suitcase', 'verb': 'open'},
#  {'id': '513', 'object': 'suitcase', 'verb': 'pack'},
#  {'id': '514', 'object': 'suitcase', 'verb': 'pick_up'},
#  {'id': '515', 'object': 'suitcase', 'verb': 'zip'},
#  {'id': '516', 'object': 'suitcase', 'verb': 'no_interaction'},
#  {'id': '517', 'object': 'surfboard', 'verb': 'carry'},
#  {'id': '518', 'object': 'surfboard', 'verb': 'drag'},
#  {'id': '519', 'object': 'surfboard', 'verb': 'hold'},
#  {'id': '520', 'object': 'surfboard', 'verb': 'inspect'},
#  {'id': '521', 'object': 'surfboard', 'verb': 'jump'},
#  {'id': '522', 'object': 'surfboard', 'verb': 'lie_on'},
#  {'id': '523', 'object': 'surfboard', 'verb': 'load'},
#  {'id': '524', 'object': 'surfboard', 'verb': 'ride'},
#  {'id': '525', 'object': 'surfboard', 'verb': 'stand_on'},
#  {'id': '526', 'object': 'surfboard', 'verb': 'sit_on'},
#  {'id': '527', 'object': 'surfboard', 'verb': 'wash'},
#  {'id': '528', 'object': 'surfboard', 'verb': 'no_interaction'},
#  {'id': '529', 'object': 'teddy_bear', 'verb': 'carry'},
#  {'id': '530', 'object': 'teddy_bear', 'verb': 'hold'},
#  {'id': '531', 'object': 'teddy_bear', 'verb': 'hug'},
#  {'id': '532', 'object': 'teddy_bear', 'verb': 'kiss'},
#  {'id': '533', 'object': 'teddy_bear', 'verb': 'no_interaction'},
#  {'id': '534', 'object': 'tennis_racket', 'verb': 'carry'},
#  {'id': '535', 'object': 'tennis_racket', 'verb': 'hold'},
#  {'id': '536', 'object': 'tennis_racket', 'verb': 'inspect'},
#  {'id': '537', 'object': 'tennis_racket', 'verb': 'swing'},
#  {'id': '538', 'object': 'tennis_racket', 'verb': 'no_interaction'},
#  {'id': '539', 'object': 'tie', 'verb': 'adjust'},
#  {'id': '540', 'object': 'tie', 'verb': 'cut'},
#  {'id': '541', 'object': 'tie', 'verb': 'hold'},
#  {'id': '542', 'object': 'tie', 'verb': 'inspect'},
#  {'id': '543', 'object': 'tie', 'verb': 'pull'},
#  {'id': '544', 'object': 'tie', 'verb': 'tie'},
#  {'id': '545', 'object': 'tie', 'verb': 'wear'},
#  {'id': '546', 'object': 'tie', 'verb': 'no_interaction'},
#  {'id': '547', 'object': 'toaster', 'verb': 'hold'},
#  {'id': '548', 'object': 'toaster', 'verb': 'operate'},
#  {'id': '549', 'object': 'toaster', 'verb': 'repair'},
#  {'id': '550', 'object': 'toaster', 'verb': 'no_interaction'},
#  {'id': '551', 'object': 'toilet', 'verb': 'clean'},
#  {'id': '552', 'object': 'toilet', 'verb': 'flush'},
#  {'id': '553', 'object': 'toilet', 'verb': 'open'},
#  {'id': '554', 'object': 'toilet', 'verb': 'repair'},
#  {'id': '555', 'object': 'toilet', 'verb': 'sit_on'},
#  {'id': '556', 'object': 'toilet', 'verb': 'stand_on'},
#  {'id': '557', 'object': 'toilet', 'verb': 'wash'},
#  {'id': '558', 'object': 'toilet', 'verb': 'no_interaction'},
#  {'id': '559', 'object': 'toothbrush', 'verb': 'brush_with'},
#  {'id': '560', 'object': 'toothbrush', 'verb': 'hold'},
#  {'id': '561', 'object': 'toothbrush', 'verb': 'wash'},
#  {'id': '562', 'object': 'toothbrush', 'verb': 'no_interaction'},
#  {'id': '563', 'object': 'traffic_light', 'verb': 'install'},
#  {'id': '564', 'object': 'traffic_light', 'verb': 'repair'},
#  {'id': '565', 'object': 'traffic_light', 'verb': 'stand_under'},
#  {'id': '566', 'object': 'traffic_light', 'verb': 'stop_at'},
#  {'id': '567', 'object': 'traffic_light', 'verb': 'no_interaction'},
#  {'id': '568', 'object': 'truck', 'verb': 'direct'},
#  {'id': '569', 'object': 'truck', 'verb': 'drive'},
#  {'id': '570', 'object': 'truck', 'verb': 'inspect'},
#  {'id': '571', 'object': 'truck', 'verb': 'load'},
#  {'id': '572', 'object': 'truck', 'verb': 'repair'},
#  {'id': '573', 'object': 'truck', 'verb': 'ride'},
#  {'id': '574', 'object': 'truck', 'verb': 'sit_on'},
#  {'id': '575', 'object': 'truck', 'verb': 'wash'},
#  {'id': '576', 'object': 'truck', 'verb': 'no_interaction'},
#  {'id': '577', 'object': 'umbrella', 'verb': 'carry'},
#  {'id': '578', 'object': 'umbrella', 'verb': 'hold'},
#  {'id': '579', 'object': 'umbrella', 'verb': 'lose'},
#  {'id': '580', 'object': 'umbrella', 'verb': 'open'},
#  {'id': '581', 'object': 'umbrella', 'verb': 'repair'},
#  {'id': '582', 'object': 'umbrella', 'verb': 'set'},
#  {'id': '583', 'object': 'umbrella', 'verb': 'stand_under'},
#  {'id': '584', 'object': 'umbrella', 'verb': 'no_interaction'},
#  {'id': '585', 'object': 'vase', 'verb': 'hold'},
#  {'id': '586', 'object': 'vase', 'verb': 'make'},
#  {'id': '587', 'object': 'vase', 'verb': 'paint'},
#  {'id': '588', 'object': 'vase', 'verb': 'no_interaction'},
#  {'id': '589', 'object': 'wine_glass', 'verb': 'fill'},
#  {'id': '590', 'object': 'wine_glass', 'verb': 'hold'},
#  {'id': '591', 'object': 'wine_glass', 'verb': 'sip'},
#  {'id': '592', 'object': 'wine_glass', 'verb': 'toast'},
#  {'id': '593', 'object': 'wine_glass', 'verb': 'lick'},
#  {'id': '594', 'object': 'wine_glass', 'verb': 'wash'},
#  {'id': '595', 'object': 'wine_glass', 'verb': 'no_interaction'},
#  {'id': '596', 'object': 'zebra', 'verb': 'feed'},
#  {'id': '597', 'object': 'zebra', 'verb': 'hold'},
#  {'id': '598', 'object': 'zebra', 'verb': 'pet'},
#  {'id': '599', 'object': 'zebra', 'verb': 'watch'},
#  {'id': '600', 'object': 'zebra', 'verb': 'no_interaction'}]
